# %%
from nilearn import plotting
import numpy as np
import siibra
# Out:
# /Users/tdickscheid/src/siibra-python/.venv/lib/python3.9/site-packages/nilearn/datasets/__init__.py:93: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "
# [siibra:INFO] Version: 0.3a7
# [siibra:WARNING] This is a development release. Use at your own risk.
# [siibra:INFO] Please file bugs and issues at https://github.com/FZJ-INM1-BDA/siibra-python.
# [siibra:INFO] Loaded 87 region spec aliases for human

# %% [markdown]
# # Allen mouse brain atlas

# %%
atlas = siibra.atlases['mouse v3']
mousetpl = atlas.get_template().fetch()
parcellationmap = atlas.get_map().fetch()
plotting.plot_roi(parcellationmap,bg_img=mousetpl,vmax=10000)
# Out:
# [siibra:INFO] No parcellation specified, using default 'Allen Mouse Common Coordinate Framework v3 2017'.
# [siibra:WARNING] 638 parcellation indices in labelled volume couldn't be matched to region definitions in Allen Mouse Common Coordinate Framework v3 2017

# %% [markdown]
# # Waxholm space atlas of the sprague dawley rat brain

# %%
atlas = siibra.atlases['waxholm rat']
waxholmtpl = atlas.get_template().fetch()
for v in ["v3","v4"]:
    parcellationmap = atlas.get_map(parcellation=v).fetch()
    plotting.plot_roi(parcellationmap,bg_img=waxholmtpl,cmap="Set2")
# Out:
# [siibra:WARNING] 112 parcellation indices in labelled volume couldn't be matched to region definitions in Waxholm Space rat brain atlas v3
# [siibra:WARNING] 214 parcellation indices in labelled volume couldn't be matched to region definitions in Waxholm Space rat brain atlas v4

# %% [markdown]
# # Human brain atlas

# %% [markdown]
# ## MNI space

# %%
atlas = siibra.atlases['human']
mni152tpl = atlas.get_template("mni152").fetch()
parcellationmap = atlas.get_map(space="mni152", parcellation="julich 2.9")
for img in parcellationmap.fetch_iter():
    plotting.plot_roi(img,bg_img=mni152tpl,cut_coords=[0,0,0],cmap='Set1')

# %% [markdown]
# ## BigBrain space

# %%
reso = 0.64
bigbrain = atlas.get_template("bigbrain").fetch(resolution_mm=reso)
parcellationmap = atlas.get_map("bigbrain").fetch(resolution_mm=reso)
plotting.plot_roi(parcellationmap,bg_img=bigbrain,cut_coords=[0,0,0],cmap='Set1')
# Out:
# [siibra:INFO] No parcellation specified, using default 'Julich-Brain Cytoarchitectonic Maps 2.9'.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-a1e657362b9a> in <module>
#       1 reso = 0.64
#       2 bigbrain = atlas.get_template("bigbrain").fetch(resolution_mm=reso)
# ----> 3 parcellationmap = atlas.get_map("bigbrain").fetch(resolution_mm=reso)
#       4 plotting.plot_roi(parcellationmap,bg_img=bigbrain,cut_coords=[0,0,0],cmap='Set1')
#
# ~/src/siibra-python/siibra/core/atlas.py in get_map(self, space, parcellation, maptype)
#     180         parc_obj = self.get_parcellation(parcellation)
#     181         space_obj = self.get_space(space)
# --> 182         return parc_obj.get_map(space=space_obj, maptype=maptype)
#     183
#     184     def get_region(self, region, parcellation=None):
#
# ~/src/siibra-python/siibra/core/parcellation.py in get_map(self, space, maptype)
#     214                 )
#     215
# --> 216         return ParcellationMap.get_instance(self, spaceobj, maptype)
#     217
#     218     @property
#
# ~/src/siibra-python/siibra/volumes/parcellationmap.py in get_instance(cls, parcellation, space, maptype)
#     101         else:
#     102             raise ValueError(f"Invalid maptype: '{maptype}'")
# --> 103         if len(obj) == 0:
#     104             raise ValueError(
#     105                 f"No data found to construct a {maptype} map for {parcellation.name} in {space.name}."
#
# ~/src/siibra-python/siibra/volumes/parcellationmap.py in __len__(self)
#     188         Returns the number of maps available in this parcellation.
#     189         """
# --> 190         return len(self.maploaders)
#     191
#     192     def __contains__(self, spec):
#
# ~/src/siibra-python/siibra/volumes/parcellationmap.py in maploaders(self)
#     112     def maploaders(self):
#     113         if self._maploaders_cached is None:
# --> 114             self._define_maps_and_regions()
#     115         return self._maploaders_cached
#     116
#
# ~/src/siibra-python/siibra/volumes/parcellationmap.py in _define_maps_and_regions(self)
#     427         else:
#     428             # reached only if for loop was not interrupted by 'break'
# --> 429             raise RuntimeError(
#     430                 f"No suitable volume source for {self.parcellation.name} in {self.space.name}"
#     431             )
#
# RuntimeError: No suitable volume source for Julich-Brain Cytoarchitectonic Maps 2.9 in Big Brain

# %%
atlas.get_template("mni152").fetch()
